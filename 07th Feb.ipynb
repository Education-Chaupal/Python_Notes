# %%
def sum(a,b):
  c = a+b
  return c

# %%
def sum1(a,b):
  return a+b

# %%
sum(4,6)
# Out:
# 10

# %%
sum(15,16)
# Out:
# 31

# %%
def sum(a,b):
  sum  = a+b
  return sum

def multiply(c):
  return c*4

# %%
sum = sum(4,6)

# %%
multi = multiply(sum)

# %%
multi
# Out:
# 40

# %%
def result(a,b):
  sum1 = sum(a,b)
  multi = multiply(sum1)
  return multi

# %%
result(12,14)
# Out:
# 104

# %%
def computing_square(c):
  z = c**3
  return z

# %%
computing_square(12)
# Out:
# 1728

# %%
def evenodd(num):
  if(num%2==0):
     print(num)
  else:
     print(num)
evenodd(13)
# Out:
# 13

# %%
evenodd(12)
# Out:
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# ...

# %%
def fun(a):
  if (a%2==0):
    return("even")
  else:
    return("odd")

# %%
fun(2)
# Out:
# 'even'
